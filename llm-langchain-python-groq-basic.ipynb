# %% [markdown]
# ## LangChain and Agentic AI, Powered by Groq

# %% [markdown]
# ### Register Key (Groq)
# - open https://console.groq.com
# - create Key

# %% [markdown]
# ### Install Langchain

# %%
# !pip install langchain
# !pip install langchain-groq
# !pip install python-dotenv
# Out:
# ...
# WARNING: Ignoring invalid distribution ~ip (C:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Python311\Lib\site-packages)
# ...
# WARNING: Ignoring invalid distribution ~ip (C:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Python311\Lib\site-packages)
# ...
# WARNING: Ignoring invalid distribution ~ip (C:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Python311\Lib\site-packages)

# %% [markdown]
# ### Initialization AI  using Grog (Meta Llama 3.1 8B model)

# %%
import os
from dotenv import load_dotenv
from langchain_groq import ChatGroq
from langchain_core.prompts import ChatPromptTemplate

load_dotenv()

llm = ChatGroq(
    model="llama-3.1-8b-instant",  # Updated to the currently active model
    temperature=0.7,
)

# %% [markdown]
# ### Create the Algoritm

# %%
# Create a Prompt Template
prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a senior AI assistant in an automotive company. Respond in English."),
    ("user", "Briefly explain the function of the {component} component in a car.")
])

# Connect the components into a single pipeline (Chain)
chain = prompt | llm

# %%
# Run the AI by passing the desired variables
# Start play here by changing "Carburetor"  to other words or try: "Turbocharger" or try: "ECU (Engine Control Unit)"

print("Asking Llama 3 via Groq (Free)...")
respons = chain.invoke({"component": "Turbocharger"})
# Out:
# Asking Llama 3 via Groq (Free)...

# %%
# 5. Display the AI's response
print("\nAI Response:")
print(respons.content)
# Out:
# AI Response:
# A Turbocharger is a critical component in modern vehicles that enhances engine performance by utilizing waste energy to boost power output.
#
# Here's a brief overview of its function:
#
# 1. **Waste Energy Utilization**: The Turbocharger captures the energy wasted in the form of exhaust gases exiting the engine. This energy is then converted into rotational force.
# 2. **Boosting Pressure**: The rotational force is transferred to a turbine connected to the compressor, which compresses air entering the engine's cylinders. This compressed air increases the air-fuel mixture's density, allowing the engine to burn more fuel and produce more power.
# 3. **Increased Power**: With the increased air density, the engine can produce more power and torque, resulting in improved acceleration and performance.
# 4. **Improved Fuel Efficiency**: While the Turbocharger enhances power output, it also allows the engine to run at a lower RPM, which can lead to improved fuel efficiency.
# ...
